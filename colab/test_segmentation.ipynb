# %%
#%%

import sys
sys.path.append('/content/drive/My Drive/Segmentation')

#%%

import torch
import numpy
import matplotlib.pyplot as plt

#%%

torch.cuda.get_device_name(0)
torch.cuda.get_device_properties(0)
# Out:
# _CudaDeviceProperties(name='Tesla K80', major=3, minor=7, total_memory=11441MB, multi_processor_count=13)

# %%
# !pip install tensorboardX

from tool.test import execute
# Out:
# ...
#      |████████████████████████████████| 317kB 2.8MB/s
# ...

# %%
execute()
# Out:
# [2020-07-09 10:42:36,553 INFO test.py line 70 124] arch: deeplabv3
# aux_weight: 0.4
# base_lr: 0.01
# base_size: 428
# batch_size: 8
# batch_size_val: 3
# classes: 21
# colors_path: /content/drive/My Drive/Segmentation/dataset/voc2012/voc2012_colors.txt
# data_root: /content/drive/My Drive/Segmentation/voc2012
# dist_backend: nccl
# dist_url: tcp://127.0.0.1:6789
# epochs: 200
# evaluate: False
# has_prediction: False
# ignore_label: 255
# index_start: 0
# index_step: 0
# keep_batchnorm_fp32: None
# layers: 101
# loss_scale: None
# manual_seed: None
# model_path: /content/drive/My Drive/Segmentation/voc2012/deeplab_v3_313/train_epoch_200.pth
# momentum: 0.9
# multiprocessing_distributed: False
# names_path: /content/drive/My Drive/Segmentation/dataset/voc2012/voc2012_names.txt
# opt_level: O0
# power: 0.9
# print_freq: 10
# rank: 0
# resume: /content/drive/My Drive/Segmentation/voc2012/deeplabv3_101_image_353/model/train_epoch_4.pth
# rotate_max: 10
# rotate_min: -10
# ...

# %%
from tool.colorize_image import colorize
colorize()
